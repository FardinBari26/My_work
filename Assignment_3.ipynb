# %% [markdown]
# <a href="https://colab.research.google.com/github/FardinBari26/My_work/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# H1: Write a function to calculate the sum of numbers from 1 to N.

def sum_of_numbers(N):
  sum = 0
  for i in range(1,N+1):
    sum = sum + i
  print(sum)

N = int(input("Enter a number: "))
sum_of_numbers(N)
# Out:
# Enter a number: 10
# 55

# %%
# H2: Write a function that returns the square of a number.

def square_of_number(number):
  square = number * number
  print(square)

number = float(input("Enter a number: "))
square_of_number(number)
# Out:
# Enter a number: 10
# 100.0

# %%
# H3: Write a function that checks whether a number is even/odd.

def check_even_odd(number):
  if number % 2 == 0:
    print("Even")
  else:
    print("Odd")

number = int(input("Enter a number: "))
check_even_odd(number)
# Out:
# Enter a number: 2
# Even

# %%
# H4: Write a function that returns the larger number from two given numbers.

def larger_number(num1, num2):
    sum = num1 + num2
    print(sum)

num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
larger_number(num1, num2)
# Out:
# Enter a number: 5
# Enter a number: 9
# 14
