# %% [markdown]
# <a href="https://colab.research.google.com/github/FardinBari26/My_work/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# H1: Write a program to perform the subtraction, multipllication and division
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# subtraction
subtraction = num1 - num2
print("Subtraction:", subtraction)

# multipllicatiom
multiplication = num1 * num2
print("Multiplication:", multiplication)

# division
division = num1/num2
print("Division:",division)
# Out:
# Enter first number: 20
# Enter second number: 10
# Subtraction: 10
# Multiplication: 200
# Division: 2.0

# %%
# H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.

id, name, batch, hometown = 211306, "Fardin Bari", "Nine batch", "Rajbari"

print("id:", id)
print("name:", name)
print("batch:", batch)
print("hometown:", hometown)
# Out:
# id: 211306
# name: Fardin Bari
# batch: Nine batch
# hometown: Rajbari

# %%
# H3: Write a program to change values of an integer variable
num = 2

num = float(num)
print(num)
print(type(num))
# Out:
# 2.0
# <class 'float'>

# %%
# H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.

num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

print(type(num1))
print(type(num2))

num1 = int(num1)
num2 = int(num2)

print(type(num1))
print(type(num2))
# Out:
# Enter first number: 26
# Enter second number: 39
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %%
# H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3)/33
print("Average:", round(average,2))
# Out:
# Enter first number: 6
# Enter second number: 5
# Enter third number: 8
# Average: 6.33

# %%
# H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /):")

if operation == "+":
    print(num1 + num2)
elif operation == "-":
    print(num1 - num2)
elif operation == "*":
    print(num1 * num2)
elif operation == "/":
    print(num1 / num2)
else:
    print("Invalid operation")
# Out:
# Enter first number: 2
# Enter second number: 5
# Enter operation (+, -, *, /):+
# 7.0

# %%
# H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant

character = input("Enter a single character: ")

if character == "a" or character == "e" or character == "i" or character == "o" or character == "u":
    print("It is a vowel")
else:
  print("It is a consonant")
# Out:
# Enter a single character: y
# It is a consonant

# %%
# H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

temperature = float(input("Enter temperature: "))
temp_unit = input("Enter temperature unit (C/F): ")

if temp_unit == "C":
  F = (9*temperature/5)+32
  print("From Celsius to Fahrenheit",F)

elif temp_unit == "F":
  C = 5*(temperature-32)/9
  print("From Fahrenheit to Celsius",C)
# Out:
# Enter temperature: 100
# Enter temperature unit (C/F): F
# From Fahrenheit to Celsius 37.77777777777778

# %%
# H9: Write a program that asks the user to enter three numbers and determines which one is the largest.

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 > num2 and num1 > num3:
  print(num1, "is the largest number")

elif num2 > num1 and num2 > num3:
  print(num2, "is the largest number")
else:
  print(num3, "is the largest number")
# Out:
# Enter first number: 9
# Enter second number: 14
# Enter third number: 20
# 20.0 is the largest number

# %%
# H10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.
N = int(input("Enter a number (N): "))

print(f"Even numbers between 1 and {N}:")
for i in range(1, N + 1):
    if i % 2 == 0:
        print(i)
# Out:
# Enter a number (N): 10
# Even numbers between 1 and 10:
# 2
# 4
# 6
# 8
# 10

# %%
# H11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.
N = int(input("Enter a number (N): "))

sum_divisible = 0
for i in range(1, N + 1):
    if (i % 3 == 0) or (i % 5 == 0):
        sum_divisible += i

print(f"The sum of numbers divisible by 3 or 5 up to {N} is: {sum_divisible}")
# Out:
# Enter a number (N): 10
# The sum of numbers divisible by 3 or 5 up to 10 is: 33

# %%
# H12: Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop
n = int(input("Enter a number (n): "))

print(f"Multiplication Table for {n}:")
for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")
# Out:
# Enter a number (n): 9
# Multiplication Table for 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
