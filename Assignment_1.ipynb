# %% [markdown]
# <a href="https://colab.research.google.com/github/FardinBari26/My_work/blob/main/my_first_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is my first python code (SM-ML-2026-B2-035)

print("Hello! World.Here comes Fardin.", sep)
# Out:
# Hello! World.Here comes Fardin.

# %%
# f6
